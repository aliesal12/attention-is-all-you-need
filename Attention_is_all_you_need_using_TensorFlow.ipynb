# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Reshape, Embedding, LayerNormalization, Softmax, ReLU
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
from keras.initializers import GlorotUniform
from keras.regularizers import L1L2
import tensorflow as tf
import math

# %%
def generate_vocab(sentences):
  """
    sentences: (list of str) sentences
    unique_words: (list of str) unique words in the training examples
    V: (int) Size of Vocabulary
    word_to_id: (dict) mapping of words to ids
    id_to_word: (dict) mapping of ids to words
  """
  unique_words = list(set(" ".join(sentences).split()))
  unique_words = ["[PAD]", "[UNK]"] + unique_words
  V = len(unique_words)

  word_to_id = {w: i for i, w in enumerate(unique_words)}
  id_to_word = {i: w for i, w in enumerate(unique_words)}
  return V, word_to_id, id_to_word

# %%
def tokenization(sentences, d=32, padding_size=4, decoder=False):
  """
    sentences: (list of str) sentences
    padding_size: (int) Size of padding
    d: (int) embedding dimension
    unique_words: (list of str) unique words in the training examples
    V: (int) Size of Vocabulary
    word_to_id: (dict) mapping of word to ids
    id_to_word: (dict) mapping of ids to words
    m: (int) number of training examples
    n: (int) sequence length in a single example
    word_ids: (numpy array) tokenized word IDs of shape (m, n)
    word_ids_shifted: (numpy array, optional) tokenized word IDs shifted for decoder of shape (m, n)
  """
  sentences = ["<START> "+s+" <END>" for s in sentences]

  V, word_to_id, id_to_word = generate_vocab(sentences)
  m=len(sentences)
  n=padding_size
  split_sentences = [sentence.split() for sentence in sentences]

  pad_id = word_to_id["[PAD]"]
  unk_id = word_to_id["[UNK]"]
  word_ids = np.full((m, n), pad_id, dtype=int)

  for i, words in enumerate(split_sentences):
    truncated = words[:padding_size]

    if decoder:
      truncated_shifted=[j for j in truncated if j!='<END>']
      mapped_shifted=[word_to_id.get(word, unk_id) for word in truncated_shifted]
      word_ids_shifted=word_ids[:,:-1]
      word_ids_shifted[i, :len(mapped_shifted)] = mapped_shifted

    mapped = [word_to_id.get(word, unk_id) for word in truncated]
    word_ids[i, :len(mapped)] = mapped
  if decoder:
    return word_to_id, id_to_word, V, d, n, m, word_ids_shifted, word_ids
  return word_to_id, id_to_word, V, d, n, m, word_ids

# %%
sentences_eng=['the dog is not sitting','the cat is sitting','a cat is playing','the dog is not playing','a cat is not sitting']

sentences_spa=['el perro no esta sentado','el gato esta sentado','un gato esta jugando','el perro no esta jugando','un gato no esta sentado']

word_to_id_en, id_to_word_en, vocab_size_en, dimension, sequence_length_en, batch_size, word_ids_en = tokenization(sentences_eng, d=8, padding_size=7)

word_to_id_dec, id_to_word_dec, vocab_size_dec, dimension, sequence_length_dec, batch_size, word_ids_shifted, target = tokenization(sentences_spa, d=8, padding_size=7, decoder = True)

# %%
heads = 2
expansion_dim = dimension * 4
num_layers_enc_dec = 6

# %%
class CustomEmbedding(tf.keras.layers.Layer):
  def __init__(self, dimension, vocab_size):
    super().__init__()
    self.embeddings = Embedding(vocab_size, dimension, embeddings_initializer=GlorotUniform(), embeddings_regularizer=L1L2(), mask_zero=True)

  def call(self, x):
    return self.embeddings(x)

# %%
class Position_Encoding(tf.keras.layers.Layer):
  def __init__(self, dimension, seq_len):
    super().__init__()
    position = np.arange(seq_len)[:, np.newaxis]
    div_term = 10000 ** (np.arange(dimension)/ dimension)
    self.pos_enc = position / div_term
    self.pos_enc[:,0::2] = np.sin(self.pos_enc[:,0::2])
    self.pos_enc[:,1::2] = np.sin(self.pos_enc[:,1::2])
    self.pos_enc = tf.convert_to_tensor(self.pos_enc, dtype=tf.float32)

  def call(self, x):
    return x + self.pos_enc[:x.shape[1]]

# %%
class SelfAttention(tf.keras.layers.Layer):
  def __init__(self, heads, dimension):
    super().__init__()
    self.heads = heads
    self.head_dim = int(dimension/self.heads)
    self.dimension = dimension

    self.Q = Dense(self.head_dim)
    self.K = Dense(self.head_dim)
    self.V = Dense(self.head_dim)

    self.softmax = Softmax()

    self.linear = Dense(self.dimension)
    self.norm = LayerNormalization()

  def get_mask(self, attention_scores):
    batch, heads, query_len, key_len = attention_scores.shape
    mask = tf.experimental.numpy.tril(tf.ones((query_len, key_len)))
    mask = tf.expand_dims(tf.expand_dims(mask,axis=0), axis=1)
    return mask

  def call(self, q, k, v, m=False):
    batch = q.shape[0]
    q_len = q.shape[1]
    k_len = k.shape[1]
    v_len = v.shape[1]

    Q = self.Q(tf.reshape(q, [batch, q_len, self.heads, self.head_dim]))
    K = self.K(tf.reshape(k, [batch, k_len, self.heads, self.head_dim]))
    V = self.V(tf.reshape(v,[batch, v_len, self.heads, self.head_dim]))

    dot_Q_K = tf.einsum("bqhd, bkhd -> bhqk", Q, K) / math.sqrt(self.dimension)

    if m:
      mask = self.get_mask(dot_Q_K)
      dot_Q_K = tf.where(mask == 0, tf.fill(tf.shape(dot_Q_K), float('-inf')), dot_Q_K)

    softmaxx = self.softmax(dot_Q_K)

    attention = tf.einsum("bhqk, bvhd -> bqhd", softmaxx, V)

    multi_heads = tf.reshape(attention, [batch, q_len, self.dimension])

    linear = self.linear(multi_heads)

    addnorm = self.norm(linear + q)

    return addnorm

# %%
class FeedForward(tf.keras.layers.Layer):
  def __init__(self, dimension, expansion_dim):
    super().__init__()
    self.linear1 = Dense(expansion_dim, activation='relu')
    self.linear2 = Dense(dimension)
    self.norm = LayerNormalization()

  def call(self, x):
    return self.norm(x + self.linear2(self.linear1(x)))

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, heads, dimension, expansion_dim):
    super().__init__()
    self.attention = SelfAttention(heads, dimension)
    self.ff = FeedForward(dimension, expansion_dim)

  def call(self, q, k, v):
    multiheadout = self.attention(q,k,v)
    return self.ff(multiheadout)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, heads, dimension, expansion_dim):
    super().__init__()
    self.masked_attention = SelfAttention(heads, dimension)
    self.attention = SelfAttention(heads, dimension)
    self.ff = FeedForward(dimension, expansion_dim)

  def call(self, q, k_dec, v_dec, k_en, v_en):
    masked_headout = self.masked_attention(q, k_dec, v_dec, m=True)
    multiheadout = self.attention(masked_headout, k_en, v_en)
    feed_forw = self.ff(multiheadout)
    return feed_forw

# %%
class Transformer(tf.keras.layers.Layer):
  def __init__(self, dimension, vocab_size_en, vocab_size_dec, sequence_length_en, sequence_length_dec, heads, expansion_dim, N):
    super().__init__()
    self.embedding_enc = CustomEmbedding(dimension, vocab_size_en)
    self.embedding_dec = CustomEmbedding(dimension, vocab_size_dec)
    self.pos_enc_en = Position_Encoding(dimension, sequence_length_en)
    self.pos_enc_dec = Position_Encoding(dimension, sequence_length_dec)
    self.encoder = [Encoder(heads, dimension, expansion_dim) for _ in range(N)]
    self.decoder = [Decoder(heads, dimension, expansion_dim) for _ in range(N)]
    self.linear = Dense(vocab_size_dec)

  def call(self, inn):
    word_ids_en = inn[0]
    print(word_ids_en.shape)
    word_ids_dec = inn[1]
    embeddings_en = self.embedding_enc(word_ids_en)
    embeddings_dec = self.embedding_dec(word_ids_dec)
    enc_in = self.pos_enc_en(embeddings_en)
    dec_in = self.pos_enc_dec(embeddings_dec)
    for enc in self.encoder:
        enc_in = enc(enc_in, enc_in, enc_in)
    for dec in self.decoder:
        dec_in = dec(dec_in, dec_in, dec_in, enc_in, enc_in)
    out = self.linear(dec_in)
    return out

# %%
word_ids_en_tensor = tf.convert_to_tensor(word_ids_en, dtype=tf.int64)
word_ids_dec_tensor = tf.convert_to_tensor(word_ids_shifted, dtype=tf.int64)

target_label_tensor = tf.convert_to_tensor(word_ids_shifted, dtype=tf.int64)

# %%
transformerr = Sequential([Transformer(dimension, vocab_size_en, vocab_size_dec, sequence_length_en, sequence_length_dec, heads, expansion_dim, num_layers_enc_dec)])
transformerr.compile(optimizer=Adam(learning_rate=1e-4), loss=SparseCategoricalCrossentropy(from_logits=True))

# %%
transformerr.fit((word_ids_en_tensor, word_ids_dec_tensor), target_label_tensor, batch_size=5, epochs=5000)
# Out:
# Epoch 1/5000
# (5, 7)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:915: UserWarning: Layer 'position__encoding' (of type Position_Encoding) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:915: UserWarning: Layer 'position__encoding_1' (of type Position_Encoding) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Epoch 2501/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8871
# Epoch 2502/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8870
# Epoch 2503/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8870
# Epoch 2504/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8869
# Epoch 2505/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8868
# Epoch 2506/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8868
# Epoch 2507/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8867
# Epoch 2508/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8867
# Epoch 2509/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8866
# Epoch 2510/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8866
# Epoch 2511/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8865
# Epoch 2512/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8864
# Epoch 2513/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8864
# Epoch 2514/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8863
# Epoch 2515/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8863
# Epoch 2516/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8862
# Epoch 2517/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8862
# Epoch 2518/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8861
# Epoch 2519/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8860
# Epoch 2520/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8860
# Epoch 2521/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8859
# Epoch 2522/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8859
# Epoch 2523/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8858
# Epoch 2524/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8858
# Epoch 2525/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8857
# Epoch 2526/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8857
# Epoch 2527/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8856
# Epoch 2528/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8855
# Epoch 2529/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8855
# Epoch 2530/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8854
# Epoch 2531/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8854
# Epoch 2532/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8853
# Epoch 2533/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8853
# Epoch 2534/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8852
# Epoch 2535/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8851
# Epoch 2536/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8851
# Epoch 2537/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8850
# Epoch 2538/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8850
# Epoch 2539/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8849
# Epoch 2540/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8849
# Epoch 2541/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8848
# Epoch 2542/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8848
# Epoch 2543/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8847
# Epoch 2544/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8846
# Epoch 2545/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8846
# Epoch 2546/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8845
# Epoch 2547/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8845
# Epoch 2548/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8844
# Epoch 2549/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8844
# Epoch 2550/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.8843
# Epoch 2551/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.8843
# Epoch 2552/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8842
# Epoch 2553/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8841
# Epoch 2554/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.8841
# Epoch 2555/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8840
# Epoch 2556/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8840
# Epoch 2557/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 1.8839
# Epoch 2558/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8839
# Epoch 2559/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.8838
# Epoch 2560/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8838
# Epoch 2561/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 1.8837
# Epoch 2562/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8836
# Epoch 2563/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8836
# Epoch 2564/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8835
# Epoch 2565/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 1.8835
# Epoch 2566/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8834
# Epoch 2567/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.8834
# Epoch 2568/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.8833
# Epoch 2569/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.8833
# Epoch 2570/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.8832
# Epoch 2571/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8832
# Epoch 2572/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8831
# Epoch 2573/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.8830
# Epoch 2574/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8830
# Epoch 2575/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.8829
# Epoch 2576/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8829
# Epoch 2577/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.8828
# Epoch 2578/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8828
# Epoch 2579/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.8827
# Epoch 2580/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8827
# Epoch 2581/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8826
# Epoch 2582/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8826
# Epoch 2583/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8825
# Epoch 2584/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8824
# Epoch 2585/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8824
# Epoch 2586/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8823
# Epoch 2587/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.8823
# Epoch 2588/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8822
# Epoch 2589/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8822
# Epoch 2590/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8821
# Epoch 2591/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8821
# Epoch 2592/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8820
# Epoch 2593/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8820
# Epoch 2594/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8819
# Epoch 2595/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1.8819
# Epoch 2596/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8819
# Epoch 2597/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8819
# Epoch 2598/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8819
# Epoch 2599/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8820
# Epoch 2600/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8820
# Epoch 2601/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8820
# Epoch 2602/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8818
# Epoch 2603/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8816
# Epoch 2604/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8814
# Epoch 2605/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8813
# Epoch 2606/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8814
# Epoch 2607/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8814
# Epoch 2608/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8814
# Epoch 2609/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8812
# Epoch 2610/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8811
# Epoch 2611/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8810
# Epoch 2612/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8810
# Epoch 2613/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8810
# Epoch 2614/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8809
# Epoch 2615/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8808
# Epoch 2616/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8807
# Epoch 2617/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8807
# Epoch 2618/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8807
# Epoch 2619/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8806
# Epoch 2620/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8805
# Epoch 2621/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8805
# Epoch 2622/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8804
# Epoch 2623/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8804
# Epoch 2624/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8803
# Epoch 2625/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.8803
# Epoch 2626/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8802
# Epoch 2627/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8801
# Epoch 2628/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8801
# Epoch 2629/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8801
# Epoch 2630/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8800
# Epoch 2631/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8799
# Epoch 2632/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.8799
# Epoch 2633/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.8798
# Epoch 2634/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8798
# Epoch 2635/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.8797
# Epoch 2636/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8797
# Epoch 2637/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8796
# Epoch 2638/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8796
# Epoch 2639/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8795
# Epoch 2640/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8795
# Epoch 2641/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8794
# Epoch 2642/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8794
# Epoch 2643/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.8793
# Epoch 2644/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8792
# Epoch 2645/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8792
# Epoch 2646/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8791
# Epoch 2647/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8791
# Epoch 2648/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8790
# Epoch 2649/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8790
# Epoch 2650/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8789
# Epoch 2651/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8789
# Epoch 2652/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.8788
# Epoch 2653/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8788
# Epoch 2654/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8787
# Epoch 2655/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8787
# Epoch 2656/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8786
# Epoch 2657/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8786
# Epoch 2658/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8785
# Epoch 2659/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8785
# Epoch 2660/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8784
# Epoch 2661/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8784
# Epoch 2662/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8783
# Epoch 2663/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8783
# Epoch 2664/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8782
# Epoch 2665/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8781
# Epoch 2666/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8781
# Epoch 2667/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.8780
# Epoch 2668/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8780
# Epoch 2669/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8779
# Epoch 2670/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8779
# Epoch 2671/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.8778
# Epoch 2672/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.8778
# Epoch 2673/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8777
# Epoch 2674/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8777
# Epoch 2675/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8776
# Epoch 2676/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.8776
# Epoch 2677/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.8775
# Epoch 2678/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1.8775
# Epoch 2679/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8774
# Epoch 2680/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1.8774
# Epoch 2681/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8773
# Epoch 2682/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 1.8773
# Epoch 2683/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8772
# Epoch 2684/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8772
# Epoch 2685/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 1.8771
# Epoch 2686/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.8771
# Epoch 2687/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8770
# Epoch 2688/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8770
# Epoch 2689/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.8769
# Epoch 2690/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8769
# Epoch 2691/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8768
# Epoch 2692/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8768
# Epoch 2693/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8767
# Epoch 2694/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8767
# Epoch 2695/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.8766
# Epoch 2696/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.8766
# Epoch 2697/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8765
# Epoch 2698/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8765
# Epoch 2699/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8764
# Epoch 2700/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8764
# Epoch 2701/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8763
# Epoch 2702/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8763
# Epoch 2703/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8762
# Epoch 2704/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8762
# Epoch 2705/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8761
# Epoch 2706/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8761
# Epoch 2707/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1.8760
# Epoch 2708/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8760
# Epoch 2709/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8759
# Epoch 2710/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8759
# Epoch 2711/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8758
# Epoch 2712/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8758
# Epoch 2713/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8758
# Epoch 2714/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8757
# Epoch 2715/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8757
# Epoch 2716/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8756
# Epoch 2717/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8756
# Epoch 2718/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.8755
# Epoch 2719/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8754
# Epoch 2720/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8754
# Epoch 2721/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8753
# Epoch 2722/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8753
# Epoch 2723/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8752
# Epoch 2724/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8752
# Epoch 2725/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8751
# Epoch 2726/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8751
# Epoch 2727/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8750
# Epoch 2728/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8750
# Epoch 2729/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8749
# Epoch 2730/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8749
# Epoch 2731/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8748
# Epoch 2732/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8748
# Epoch 2733/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8747
# Epoch 2734/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.8747
# Epoch 2735/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8746
# Epoch 2736/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8746
# Epoch 2737/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8745
# Epoch 2738/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8745
# Epoch 2739/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8744
# Epoch 2740/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8744
# Epoch 2741/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8743
# Epoch 2742/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8743
# Epoch 2743/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8742
# Epoch 2744/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8742
# Epoch 2745/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8741
# Epoch 2746/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8741
# Epoch 2747/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8740
# Epoch 2748/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8740
# Epoch 2749/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8739
# Epoch 2750/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8739
# Epoch 2751/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8738
# Epoch 2752/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8738
# Epoch 2753/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8737
# Epoch 2754/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8737
# Epoch 2755/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8736
# Epoch 2756/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8736
# Epoch 2757/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.8735
# Epoch 2758/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8735
# Epoch 2759/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8734
# Epoch 2760/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8734
# Epoch 2761/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8734
# Epoch 2762/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8733
# Epoch 2763/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8733
# Epoch 2764/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8733
# Epoch 2765/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8733
# Epoch 2766/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8733
# Epoch 2767/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8733
# Epoch 2768/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8732
# Epoch 2769/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8731
# Epoch 2770/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8730
# Epoch 2771/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.8729
# Epoch 2772/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.8728
# Epoch 2773/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8728
# Epoch 2774/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8727
# Epoch 2775/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8727
# Epoch 2776/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8729
# Epoch 2777/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8739
# Epoch 2778/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8747
# Epoch 2779/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8772
# Epoch 2780/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8732
# Epoch 2781/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8739
# Epoch 2782/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8754
# Epoch 2783/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8727
# Epoch 2784/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8753
# Epoch 2785/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8746
# Epoch 2786/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8733
# Epoch 2787/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8749
# Epoch 2788/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8722
# Epoch 2789/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8741
# Epoch 2790/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8724
# Epoch 2791/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8729
# Epoch 2792/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8728
# Epoch 2793/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.8725
# Epoch 2794/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.8725
# Epoch 2795/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8722
# Epoch 2796/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8723
# Epoch 2797/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8720
# Epoch 2798/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.8722
# Epoch 2799/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8717
# Epoch 2800/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8719
# Epoch 2801/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8717
# Epoch 2802/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 1.8717
# Epoch 2803/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8716
# Epoch 2804/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8716
# Epoch 2805/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.8713
# Epoch 2806/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8714
# Epoch 2807/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.8713
# Epoch 2808/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.8712
# Epoch 2809/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8712
# Epoch 2810/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.8712
# Epoch 2811/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 1.8710
# Epoch 2812/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8710
# Epoch 2813/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8710
# Epoch 2814/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.8709
# Epoch 2815/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.8708
# Epoch 2816/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8708
# Epoch 2817/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8707
# Epoch 2818/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8707
# Epoch 2819/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8706
# Epoch 2820/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8706
# Epoch 2821/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8705
# Epoch 2822/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8705
# Epoch 2823/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8704
# Epoch 2824/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8704
# Epoch 2825/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8703
# Epoch 2826/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8702
# Epoch 2827/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8702
# Epoch 2828/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8702
# Epoch 2829/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8701
# Epoch 2830/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8701
# Epoch 2831/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8700
# Epoch 2832/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8700
# Epoch 2833/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8699
# Epoch 2834/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.8699
# Epoch 2835/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8698
# Epoch 2836/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8698
# Epoch 2837/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8697
# Epoch 2838/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8697
# Epoch 2839/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8696
# Epoch 2840/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8696
# Epoch 2841/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8695
# Epoch 2842/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8695
# Epoch 2843/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8694
# Epoch 2844/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8694
# Epoch 2845/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8693
# Epoch 2846/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8693
# Epoch 2847/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8693
# Epoch 2848/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8692
# Epoch 2849/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8692
# Epoch 2850/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 1.8691
# Epoch 2851/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8691
# Epoch 2852/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8690
# Epoch 2853/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8690
# Epoch 2854/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8689
# Epoch 2855/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8689
# Epoch 2856/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8688
# Epoch 2857/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8688
# Epoch 2858/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8687
# Epoch 2859/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8687
# Epoch 2860/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8687
# Epoch 2861/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8686
# Epoch 2862/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8686
# Epoch 2863/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8685
# Epoch 2864/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8685
# Epoch 2865/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8684
# Epoch 2866/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8684
# Epoch 2867/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8683
# Epoch 2868/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8683
# Epoch 2869/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8682
# Epoch 2870/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8682
# Epoch 2871/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8682
# Epoch 2872/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8681
# Epoch 2873/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8681
# Epoch 2874/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8680
# Epoch 2875/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8680
# Epoch 2876/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8679
# Epoch 2877/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8679
# Epoch 2878/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8678
# Epoch 2879/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8678
# Epoch 2880/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8677
# Epoch 2881/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8677
# Epoch 2882/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8677
# Epoch 2883/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8676
# Epoch 2884/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8676
# Epoch 2885/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8675
# Epoch 2886/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8675
# Epoch 2887/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8674
# Epoch 2888/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8674
# Epoch 2889/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.8673
# Epoch 2890/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8673
# Epoch 2891/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8672
# Epoch 2892/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8672
# Epoch 2893/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8671
# Epoch 2894/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8671
# Epoch 2895/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8671
# Epoch 2896/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8670
# Epoch 2897/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8670
# Epoch 2898/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8669
# Epoch 2899/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8669
# Epoch 2900/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8668
# Epoch 2901/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8668
# Epoch 2902/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8667
# Epoch 2903/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8667
# Epoch 2904/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8667
# Epoch 2905/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8666
# Epoch 2906/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.8666
# Epoch 2907/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8665
# Epoch 2908/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8665
# Epoch 2909/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8664
# Epoch 2910/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8664
# Epoch 2911/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8663
# Epoch 2912/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8663
# Epoch 2913/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 1.8663
# Epoch 2914/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 1.8662
# Epoch 2915/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8662
# Epoch 2916/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8661
# Epoch 2917/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8661
# Epoch 2918/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8660
# Epoch 2919/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.8660
# Epoch 2920/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8659
# Epoch 2921/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 1.8659
# Epoch 2922/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8659
# Epoch 2923/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.8658
# Epoch 2924/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8658
# Epoch 2925/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.8657
# Epoch 2926/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.8657
# Epoch 2927/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8656
# Epoch 2928/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8656
# Epoch 2929/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8655
# Epoch 2930/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8655
# Epoch 2931/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 1.8655
# Epoch 2932/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8654
# Epoch 2933/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1.8654
# Epoch 2934/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8653
# Epoch 2935/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 1.8653
# Epoch 2936/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.8652
# Epoch 2937/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8652
# Epoch 2938/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.8651
# Epoch 2939/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8651
# Epoch 2940/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8651
# Epoch 2941/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8650
# Epoch 2942/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8650
# Epoch 2943/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8649
# Epoch 2944/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8649
# Epoch 2945/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8648
# Epoch 2946/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8648
# Epoch 2947/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8648
# Epoch 2948/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 1.8647
# Epoch 2949/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8647
# Epoch 2950/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8646
# Epoch 2951/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8646
# Epoch 2952/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8645
# Epoch 2953/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8645
# Epoch 2954/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8644
# Epoch 2955/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8644
# Epoch 2956/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8644
# Epoch 2957/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8643
# Epoch 2958/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8643
# Epoch 2959/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8642
# Epoch 2960/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8642
# Epoch 2961/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8641
# Epoch 2962/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8641
# Epoch 2963/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8641
# Epoch 2964/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8640
# Epoch 2965/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8640
# Epoch 2966/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8640
# Epoch 2967/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8640
# Epoch 2968/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8640
# Epoch 2969/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8641
# Epoch 2970/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.8642
# Epoch 2971/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8641
# Epoch 2972/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8639
# Epoch 2973/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8637
# Epoch 2974/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8637
# Epoch 2975/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8638
# Epoch 2976/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8637
# Epoch 2977/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8635
# Epoch 2978/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8634
# Epoch 2979/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8635
# Epoch 2980/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8636
# Epoch 2981/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8637
# Epoch 2982/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8637
# Epoch 2983/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8635
# Epoch 2984/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8632
# Epoch 2985/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8633
# Epoch 2986/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8634
# Epoch 2987/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8632
# Epoch 2988/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8630
# Epoch 2989/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8630
# Epoch 2990/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8632
# Epoch 2991/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8631
# Epoch 2992/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8630
# Epoch 2993/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.8628
# Epoch 2994/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8628
# Epoch 2995/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8629
# Epoch 2996/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8627
# Epoch 2997/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8626
# Epoch 2998/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8627
# Epoch 2999/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.8626
# Epoch 3000/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8625
# Epoch 3001/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8624
# Epoch 3002/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8624
# Epoch 3003/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8624
# Epoch 3004/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8624
# Epoch 3005/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8623
# Epoch 3006/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8623
# Epoch 3007/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8622
# Epoch 3008/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8622
# Epoch 3009/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8621
# Epoch 3010/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8621
# Epoch 3011/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8621
# Epoch 3012/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8620
# Epoch 3013/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8619
# Epoch 3014/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8619
# Epoch 3015/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8619
# Epoch 3016/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8618
# Epoch 3017/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8618
# Epoch 3018/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8617
# Epoch 3019/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.8617
# Epoch 3020/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8616
# Epoch 3021/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8616
# Epoch 3022/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8616
# Epoch 3023/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8615
# Epoch 3024/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8615
# Epoch 3025/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8614
# Epoch 3026/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.8614
# Epoch 3027/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8614
# Epoch 3028/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8613
# Epoch 3029/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8613
# Epoch 3030/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8612
# Epoch 3031/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8612
# Epoch 3032/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8611
# Epoch 3033/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 1.8611
# Epoch 3034/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.8611
# Epoch 3035/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.8610
# Epoch 3036/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 1.8610
# Epoch 3037/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8609
# Epoch 3038/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 1.8609
# Epoch 3039/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.8609
# Epoch 3040/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.8608
# Epoch 3041/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.8608
# Epoch 3042/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.8607
# Epoch 3043/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.8607
# Epoch 3044/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.8606
# Epoch 3045/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8606
# Epoch 3046/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8606
# Epoch 3047/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.8605
# Epoch 3048/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.8605
# Epoch 3049/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1.8604
# Epoch 3050/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8604
# Epoch 3051/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.8604
# Epoch 3052/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8603
# Epoch 3053/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8603
# Epoch 3054/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8602
# Epoch 3055/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8602
# Epoch 3056/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.8602
# Epoch 3057/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 1.8601
# Epoch 3058/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8601
# Epoch 3059/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8600
# Epoch 3060/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8600
# Epoch 3061/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8599
# Epoch 3062/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8599
# Epoch 3063/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8599
# Epoch 3064/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8598
# Epoch 3065/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8598
# Epoch 3066/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8597
# Epoch 3067/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8597
# Epoch 3068/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8597
# Epoch 3069/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8596
# Epoch 3070/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8596
# Epoch 3071/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8595
# Epoch 3072/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8595
# Epoch 3073/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8595
# Epoch 3074/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 1.8594
# Epoch 3075/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8594
# Epoch 3076/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8593
# Epoch 3077/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8593
# Epoch 3078/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8593
# Epoch 3079/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8592
# Epoch 3080/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8592
# Epoch 3081/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8591
# Epoch 3082/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8591
# Epoch 3083/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.8591
# Epoch 3084/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8590
# Epoch 3085/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8590
# Epoch 3086/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8589
# Epoch 3087/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8589
# Epoch 3088/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.8589
# Epoch 3089/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8588
# Epoch 3090/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8588
# Epoch 3091/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8587
# Epoch 3092/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8587
# Epoch 3093/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8587
# Epoch 3094/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.8586
# Epoch 3095/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 1.8586
# Epoch 3096/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8585
# Epoch 3097/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8585
# Epoch 3098/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8585
# Epoch 3099/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8584
# Epoch 3100/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8584
# Epoch 3101/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8583
# Epoch 3102/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8583
# Epoch 3103/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8583
# Epoch 3104/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8582
# Epoch 3105/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8582
# Epoch 3106/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8581
# Epoch 3107/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8581
# Epoch 3108/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8581
# Epoch 3109/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8580
# Epoch 3110/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8580
# Epoch 3111/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8579
# Epoch 3112/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8579
# Epoch 3113/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8579
# Epoch 3114/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8578
# Epoch 3115/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8578
# Epoch 3116/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8577
# Epoch 3117/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.8577
# Epoch 3118/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8577
# Epoch 3119/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8576
# Epoch 3120/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8576
# Epoch 3121/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8575
# Epoch 3122/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8575
# Epoch 3123/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8575
# Epoch 3124/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8574
# Epoch 3125/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8574
# Epoch 3126/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8574
# Epoch 3127/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8573
# Epoch 3128/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8573
# Epoch 3129/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8572
# Epoch 3130/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8572
# Epoch 3131/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8572
# Epoch 3132/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8571
# Epoch 3133/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8571
# Epoch 3134/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8570
# Epoch 3135/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8570
# Epoch 3136/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8570
# Epoch 3137/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8569
# Epoch 3138/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8569
# Epoch 3139/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8568
# Epoch 3140/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8568
# Epoch 3141/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.8568
# Epoch 3142/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8567
# Epoch 3143/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8567
# Epoch 3144/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8566
# Epoch 3145/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8566
# Epoch 3146/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8566
# Epoch 3147/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8565
# Epoch 3148/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8565
# Epoch 3149/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8565
# Epoch 3150/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8564
# Epoch 3151/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8564
# Epoch 3152/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8563
# Epoch 3153/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8563
# Epoch 3154/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8563
# Epoch 3155/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8562
# Epoch 3156/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.8562
# Epoch 3157/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8561
# Epoch 3158/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8561
# Epoch 3159/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.8561
# Epoch 3160/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.8560
# Epoch 3161/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8560
# Epoch 3162/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.8560
# Epoch 3163/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8559
# Epoch 3164/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8559
# Epoch 3165/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.8558
# Epoch 3166/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8558
# Epoch 3167/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8558
# Epoch 3168/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.8557
# Epoch 3169/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8557
# Epoch 3170/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8556
# Epoch 3171/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8556
# Epoch 3172/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 1.8556
# Epoch 3173/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8555
# Epoch 3174/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 1.8555
# Epoch 3175/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8555
# Epoch 3176/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8554
# Epoch 3177/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8554
# Epoch 3178/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1.8553
# Epoch 3179/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 1.8553
# Epoch 3180/5000
# ...
# Epoch 4771/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8166
# Epoch 4772/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 1.8165
# Epoch 4773/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8165
# Epoch 4774/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8165
# Epoch 4775/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8165
# Epoch 4776/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8165
# Epoch 4777/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8165
# Epoch 4778/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 1.8165
# Epoch 4779/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8164
# Epoch 4780/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8164
# Epoch 4781/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8164
# Epoch 4782/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8164
# Epoch 4783/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8164
# Epoch 4784/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8164
# Epoch 4785/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8164
# Epoch 4786/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8163
# Epoch 4787/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8163
# Epoch 4788/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8163
# Epoch 4789/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8163
# Epoch 4790/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8163
# Epoch 4791/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8163
# Epoch 4792/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8163
# Epoch 4793/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.8162
# Epoch 4794/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8162
# Epoch 4795/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8162
# Epoch 4796/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8162
# Epoch 4797/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8162
# Epoch 4798/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8162
# Epoch 4799/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8162
# Epoch 4800/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8161
# Epoch 4801/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8161
# Epoch 4802/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8161
# Epoch 4803/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.8161
# Epoch 4804/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8161
# Epoch 4805/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8161
# Epoch 4806/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8161
# Epoch 4807/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8160
# Epoch 4808/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8160
# Epoch 4809/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8160
# Epoch 4810/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8160
# Epoch 4811/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8161
# Epoch 4812/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8161
# Epoch 4813/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8162
# Epoch 4814/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8165
# Epoch 4815/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8170
# Epoch 4816/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8178
# Epoch 4817/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8190
# Epoch 4818/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8190
# Epoch 4819/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8181
# Epoch 4820/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8167
# Epoch 4821/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8165
# Epoch 4822/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8171
# Epoch 4823/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8171
# Epoch 4824/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8162
# Epoch 4825/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.8163
# Epoch 4826/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8166
# Epoch 4827/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 1.8162
# Epoch 4828/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8161
# Epoch 4829/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8162
# Epoch 4830/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8161
# Epoch 4831/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.8160
# Epoch 4832/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8161
# Epoch 4833/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1.8159
# Epoch 4834/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8160
# Epoch 4835/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8159
# Epoch 4836/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.8157
# Epoch 4837/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8159
# Epoch 4838/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8158
# Epoch 4839/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8157
# Epoch 4840/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8158
# Epoch 4841/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8157
# Epoch 4842/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.8156
# Epoch 4843/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8157
# Epoch 4844/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8156
# Epoch 4845/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.8156
# Epoch 4846/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.8156
# Epoch 4847/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8155
# Epoch 4848/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 1.8155
# Epoch 4849/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1.8155
# Epoch 4850/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8155
# Epoch 4851/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8155
# Epoch 4852/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8155
# Epoch 4853/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8154
# Epoch 4854/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8154
# Epoch 4855/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8154
# Epoch 4856/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8154
# Epoch 4857/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8154
# Epoch 4858/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8153
# Epoch 4859/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8153
# Epoch 4860/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8153
# Epoch 4861/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8153
# Epoch 4862/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8153
# Epoch 4863/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8153
# Epoch 4864/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8153
# Epoch 4865/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8153
# Epoch 4866/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8152
# Epoch 4867/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8152
# Epoch 4868/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8152
# Epoch 4869/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8152
# Epoch 4870/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8152
# Epoch 4871/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8152
# Epoch 4872/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8151
# Epoch 4873/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8151
# Epoch 4874/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8151
# Epoch 4875/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8151
# Epoch 4876/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8151
# Epoch 4877/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.8151
# Epoch 4878/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8151
# Epoch 4879/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8151
# Epoch 4880/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8150
# Epoch 4881/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8150
# Epoch 4882/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8150
# Epoch 4883/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8150
# Epoch 4884/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8150
# Epoch 4885/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8150
# Epoch 4886/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8150
# Epoch 4887/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8149
# Epoch 4888/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8149
# Epoch 4889/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8149
# Epoch 4890/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8149
# Epoch 4891/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8149
# Epoch 4892/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8149
# Epoch 4893/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8149
# Epoch 4894/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8148
# Epoch 4895/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8148
# Epoch 4896/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8148
# Epoch 4897/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8148
# Epoch 4898/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8148
# Epoch 4899/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.8148
# Epoch 4900/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8148
# Epoch 4901/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8148
# Epoch 4902/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8147
# Epoch 4903/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8147
# Epoch 4904/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8147
# Epoch 4905/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8147
# Epoch 4906/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8147
# Epoch 4907/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8147
# Epoch 4908/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8147
# Epoch 4909/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.8146
# Epoch 4910/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.8146
# Epoch 4911/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8146
# Epoch 4912/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8146
# Epoch 4913/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8146
# Epoch 4914/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8146
# Epoch 4915/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8146
# Epoch 4916/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8146
# Epoch 4917/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1.8145
# Epoch 4918/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8145
# Epoch 4919/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8145
# Epoch 4920/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.8145
# Epoch 4921/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8145
# Epoch 4922/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8145
# Epoch 4923/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8145
# Epoch 4924/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.8144
# Epoch 4925/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8144
# Epoch 4926/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8144
# Epoch 4927/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8144
# Epoch 4928/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8144
# Epoch 4929/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8144
# Epoch 4930/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.8144
# Epoch 4931/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8144
# Epoch 4932/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.8143
# Epoch 4933/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8143
# Epoch 4934/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8143
# Epoch 4935/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8143
# Epoch 4936/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.8143
# Epoch 4937/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.8143
# Epoch 4938/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.8143
# Epoch 4939/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1.8143
# Epoch 4940/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8142
# Epoch 4941/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1.8142
# Epoch 4942/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8142
# Epoch 4943/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8142
# Epoch 4944/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1.8142
# Epoch 4945/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1.8142
# Epoch 4946/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 1.8142
# Epoch 4947/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8141
# Epoch 4948/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 1.8141
# Epoch 4949/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8141
# Epoch 4950/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1.8141
# Epoch 4951/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.8141
# Epoch 4952/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.8141
# Epoch 4953/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.8141
# Epoch 4954/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8141
# Epoch 4955/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.8140
# Epoch 4956/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 1.8140
# Epoch 4957/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.8140
# Epoch 4958/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.8140
# Epoch 4959/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.8140
# Epoch 4960/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.8140
# Epoch 4961/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8140
# Epoch 4962/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8140
# Epoch 4963/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.8139
# Epoch 4964/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8139
# Epoch 4965/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8139
# Epoch 4966/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 1.8139
# Epoch 4967/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.8139
# Epoch 4968/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8139
# Epoch 4969/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.8139
# Epoch 4970/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.8139
# Epoch 4971/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.8138
# Epoch 4972/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 1.8138
# Epoch 4973/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 1.8138
# Epoch 4974/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1.8138
# Epoch 4975/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.8138
# Epoch 4976/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8138
# Epoch 4977/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8138
# Epoch 4978/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8137
# Epoch 4979/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8137
# Epoch 4980/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.8137
# Epoch 4981/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8137
# Epoch 4982/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8137
# Epoch 4983/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.8137
# Epoch 4984/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 1.8137
# Epoch 4985/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8137
# Epoch 4986/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 1.8136
# Epoch 4987/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1.8136
# Epoch 4988/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8136
# Epoch 4989/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8136
# Epoch 4990/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 1.8136
# Epoch 4991/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.8136
# Epoch 4992/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 1.8136
# Epoch 4993/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.8136
# Epoch 4994/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1.8135
# Epoch 4995/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 1.8135
# Epoch 4996/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.8135
# Epoch 4997/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.8135
# Epoch 4998/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.8135
# Epoch 4999/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.8135
# Epoch 5000/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.8135
